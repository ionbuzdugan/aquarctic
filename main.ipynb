# %%
import nidaqmx
import time
import csv

import pandas as pd

from nidaqmx.constants import ThermocoupleType, TemperatureUnits
from datetime import datetime as dt

LOG_PERIOD = 0
FILENAME = 'TEST'
TC_NAMES = ['TC1','TC2','TC3']

filename = 'LOGS/'+dt.now().strftime('%Y-%m-%d-%H-%M-%S')+'_'+FILENAME+'.csv'
with open(filename,'w',newline='') as file:
    wr = csv.writer(file, quoting=csv.QUOTE_NONE)
    wr.writerow(['epoch']+TC_NAMES)

with nidaqmx.Task() as task:
    task.ai_channels.add_ai_thrmcpl_chan(
        "cDAQ1Mod1/ai0", units=TemperatureUnits.DEG_C, thermocouple_type=ThermocoupleType.K
    )
    task.ai_channels.add_ai_thrmcpl_chan(
        "cDAQ1Mod1/ai1", units=TemperatureUnits.DEG_C, thermocouple_type=ThermocoupleType.K
    )
    task.ai_channels.add_ai_thrmcpl_chan(
        "cDAQ1Mod1/ai2", units=TemperatureUnits.DEG_C, thermocouple_type=ThermocoupleType.K
    )
    while True:
        data = task.read()
        print(f"Acquired data: {data}")
        with open(filename,'a',newline='') as file:
            wr = csv.writer(file, quoting=csv.QUOTE_NONE)
            wr.writerow([time.time()]+data)
        time.sleep(LOG_PERIOD)
# Out:
# Acquired data: [27.743658179080317, 28.15658866668982, -7956788803505.591]
# Acquired data: [27.74660299393535, 28.16284395259042, -7163261822566.82]
# Acquired data: [27.749547800622036, 28.152541109076473, -6431114376710.052]
# Acquired data: [27.74292197409026, 28.15474886969131, -5773532850353.496]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 30
#      26 task.ai_channels.add_ai_thrmcpl_chan(
#      27     "cDAQ1Mod1/ai2", units=TemperatureUnits.DEG_C, thermocouple_type=ThermocoupleType.K
#      28 )
#      29 while True:
# ---> 30     data = task.read()
#      31     print(f"Acquired data: {data}")
#      32     with open(filename,'a',newline='') as file:
#
# File c:\GIT\aquarctic\venv\Lib\site-packages\nidaqmx\task\_task.py:615, in Task.read(self, number_of_samples_per_channel, timeout)
#     613     else:
#     614         data: numpy.typing.NDArray = numpy.zeros(array_shape, dtype=numpy.float64)
# --> 615         _, samples_read = self._interpreter.read_analog_f64(
#     616             self._handle, number_of_samples_per_channel, timeout,
#     617             FillMode.GROUP_BY_CHANNEL.value, data)
#     619 elif (read_chan_type == ChannelType.DIGITAL_INPUT or
#     620         read_chan_type == ChannelType.DIGITAL_OUTPUT):
#     621     if self.in_stream.di_num_booleans_per_chan == 1:
#
# File c:\GIT\aquarctic\venv\Lib\site-packages\nidaqmx\_library_interpreter.py:4163, in LibraryInterpreter.read_analog_f64(self, task, num_samps_per_chan, timeout, fill_mode, read_array)
#    4155         if cfunc.argtypes is None:
#    4156             cfunc.argtypes = [
#    4157                 lib_importer.task_handle, ctypes.c_int,
#    4158                 ctypes.c_double, ctypes.c_int,
#    4159                 wrapped_ndpointer(dtype=numpy.float64,
#    4160                 flags=('C','W')), ctypes.c_uint,
#    4161                 ctypes.POINTER(ctypes.c_int), ctypes.POINTER(c_bool32)]
# -> 4163 error_code = cfunc(
#    4164     task, num_samps_per_chan, timeout, fill_mode, read_array,
#    4165     read_array.size, ctypes.byref(samps_per_chan_read), None)
#    4166 self.check_for_error(error_code, samps_per_chan_read=samps_per_chan_read.value)
#    4167 return read_array, samps_per_chan_read.value
#
# KeyboardInterrupt:
